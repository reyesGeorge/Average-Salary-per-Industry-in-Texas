# %% [markdown]
# ## Industry Data for 2017
# Try and establish standard metrics to establish a growth timeseries per industry. The purpose is to find growing industries who could benefit from our software.

# %%
import pandas as pd
import numpy as np

# %%
iData = pd.read_csv('industryData.csv', thousands=None,header=None, names=["FIPS","Country","zero","Industry", "Employment_Size", "Firms_Number", "Establishment_Number", "Employment","Drop_Me2", "Drop_Me3", "Annual_Payroll", "Drop4"])
df = iData.drop(['zero', 'Drop_Me2', 'Drop_Me3', 'Drop4'], axis=1)
df.index = np.arange( 1, len(df) + 1)

mask = (df != '0').all(1)
df = df[mask]
to_number = ['Employment', 'Annual_Payroll', 'Establishment_Number', 'Firms_Number']
for col in to_number:
        df[col] = df[col].str.replace(',', '').astype(float)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
#df.info()
#df.Industry.value_counts()

# %%
df['Annual_Payroll'] = df['Annual_Payroll'].apply(lambda x: x*1000)
df = df.loc[(df.Industry != 'Total') & (df.FIPS == 48)]
df
# Out:
#        FIPS Country                                    Industry  \
# 17351    48   Texas  Agriculture, Forestry, Fishing and Hunting
# 17352    48   Texas  Agriculture, Forestry, Fishing and Hunting
# 17353    48   Texas  Agriculture, Forestry, Fishing and Hunting
# 17354    48   Texas  Agriculture, Forestry, Fishing and Hunting
# 17355    48   Texas  Agriculture, Forestry, Fishing and Hunting
# ...     ...     ...                                         ...
# 17732    48   Texas                   Industries not classified
# 17733    48   Texas                   Industries not classified
# 17734    48   Texas                   Industries not classified
# 17735    48   Texas                   Industries not classified
# 17737    48   Texas                   Industries not classified
#
#       Employment_Size  Firms_Number  Establishment_Number  Employment  \
# 17351      01:  Total        1037.0                1074.0      7127.0
# ...

# %% [markdown]
# ## Seperating Texas Data by Industry

# %%
Agriculture_Forestry_Fishing_and_Hunting = df.loc[df.Industry == 'Agriculture, Forestry, Fishing and Hunting'][1::]
Health_Care_and_Social_Assistance = df.loc[df.Industry == 'Health Care and Social Assistance'][1::]
Accommodation_and_Food_Services = df.loc[df.Industry == 'Accommodation and Food Services'][1::]
Professional_Scientific_and_Technical_Services = df.loc[df.Industry == 'Professional, Scientific, and Technical Services'][1::]
Retail_Trade = df.loc[df.Industry == 'Retail Trade'][1::]
Transportation_and_Warehousing = df.loc[df.Industry == 'Transportation and Warehousing'][1::]
Wholesale_Trade = df.loc[df.Industry == 'Wholesale Trade'][1::]
Finance_and_Insurance = df.loc[df.Industry == 'Finance and Insurance'][1::]
Administrative_and_Support_and_Waste_Management_and_Remediation_Services = df.loc[df.Industry == 'Administrative and Support and Waste Management and Remediation Services'][1::]
Other_Services_Except_Public_Administration = df.loc[df.Industry == 'Other Services (except Public Administration)'][1::]
Educational_Services = df.loc[df.Industry == 'Educational Services'][1::]
Real_Estate_and_Rental_and_Leasing = df.loc[df.Industry == 'Real Estate and Rental and Leasing'][1::]
# Construction = df.loc[(df.Industry == 'Construction') & (df.Employment != '0')]
Construction = df.loc[df.Industry == 'Construction'][1::]
Manufacturing = df.loc[df.Industry == 'Manufacturing'][1::]
Information = df.loc[df.Industry == 'Information'][1::]
Management_of_Companies_and_Enterprises = df.loc[df.Industry == 'Management of Companies and Enterprises'][1::]
Arts_Entertainment_and_Recreation = df.loc[df.Industry == 'Arts, Entertainment, and Recreation'][1::]
Mining_Quarrying_and_Oil_and_Gas_Extraction = df.loc[df.Industry == 'Mining, Quarrying, and Oil and Gas Extraction'][1::]
Utilities = df.loc[df.Industry == 'Utilities'][1::]
Industries_not_classified = df.loc[df.Industry == 'Industries not classified'][1::]

# %%
df_industries = pd.concat(
    {
        'Agriculture_Forestry_Fishing_and_Hunting': Agriculture_Forestry_Fishing_and_Hunting.Industry,
        'Health_Care_and_Social_Assistance': Health_Care_and_Social_Assistance.Industry,
        'Accommodation_and_Food_Services': Accommodation_and_Food_Services.Industry,
        'Professional_Scientific_and_Technical_Services': Professional_Scientific_and_Technical_Services.Industry,
        'Retail_Trade': Retail_Trade.Industry,
        'Transportation_and_Warehousing': Transportation_and_Warehousing.Industry,
        'Wholesale_Trade': Wholesale_Trade.Industry,
        'Finance_and_Insurance': Finance_and_Insurance.Industry,
        'Administrative_and_Support_and_Waste_Management_and_Remediation_Services': Administrative_and_Support_and_Waste_Management_and_Remediation_Services.Industry,
        'Other_Services_Except_Public_Administration': Other_Services_Except_Public_Administration.Industry,
        'Educational_Services': Educational_Services.Industry,
        'Real_Estate_and_Rental_and_Leasing': Real_Estate_and_Rental_and_Leasing.Industry,
        'Construction': Construction.Industry,
        'Manufacturing': Manufacturing.Industry,
        'Information': Information.Industry,
        'Management_of_Companies_and_Enterprises': Management_of_Companies_and_Enterprises.Industry,
        'Arts_Entertainment_and_Recreation': Arts_Entertainment_and_Recreation.Industry,
        'Mining_Quarrying_and_Oil_and_Gas_Extraction': Mining_Quarrying_and_Oil_and_Gas_Extraction.Industry,
        'Utilities': Utilities.Industry,
        'Industries_not_classified': Industries_not_classified.Industry
    }
)

# %%
df_industries.tail
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e7e4fd1b3354> in <module>
# ----> 1 df_industries.tail
#
# NameError: name 'df_industries' is not defined

# %% [markdown]
# ## EFR = Employee to Firms Average Ratio
# ## APFR = Annual Payroll to Firms Average Ratio

# %%
EFR_BIG_AG = Agriculture_Forestry_Fishing_and_Hunting['Annual_Payroll'].div(Agriculture_Forestry_Fishing_and_Hunting['Employment'])
APFR_BIG_AG = Agriculture_Forestry_Fishing_and_Hunting['Annual_Payroll'].div(Agriculture_Forestry_Fishing_and_Hunting['Firms_Number'])

EFR_Health_n_Social = Health_Care_and_Social_Assistance['Annual_Payroll'].div(Health_Care_and_Social_Assistance['Employment'])
APFR_Health_n_Social = Health_Care_and_Social_Assistance['Annual_Payroll'].div(Health_Care_and_Social_Assistance['Firms_Number'])

EFR_Accommodation_and_Food_Services = Accommodation_and_Food_Services['Annual_Payroll'].div(Accommodation_and_Food_Services['Employment'])
APFR_Accommodation_and_Food_Services = Accommodation_and_Food_Services['Annual_Payroll'].div(Accommodation_and_Food_Services['Firms_Number'])

EFR_Professional_Scientific_and_Technical_Services = Professional_Scientific_and_Technical_Services['Annual_Payroll'].div(Professional_Scientific_and_Technical_Services['Employment'])
APFR_Professional_Scientific_and_Technical_Services = Professional_Scientific_and_Technical_Services['Annual_Payroll'].div(Professional_Scientific_and_Technical_Services['Firms_Number'])

EFR_Retail_Trade = Retail_Trade['Annual_Payroll'].div(Retail_Trade['Employment'])
APFR_Retail_Trade = Retail_Trade['Annual_Payroll'].div(Retail_Trade['Firms_Number'])

EFR_Transportation_and_Warehousing = Transportation_and_Warehousing['Annual_Payroll'].div(Transportation_and_Warehousing['Employment'])
APFR_Transportation_and_Warehousing = Transportation_and_Warehousing['Annual_Payroll'].div(Transportation_and_Warehousing['Firms_Number'])

EFR_Wholesale_Trade = Wholesale_Trade['Annual_Payroll'].div(Wholesale_Trade['Employment'])
APFR_Wholesale_Trade = Wholesale_Trade['Annual_Payroll'].div(Wholesale_Trade['Firms_Number'])

EFR_Finance_and_Insurance = Finance_and_Insurance['Annual_Payroll'].div(Finance_and_Insurance['Employment'])
APFR_Finance_and_Insurance = Finance_and_Insurance['Annual_Payroll'].div(Finance_and_Insurance['Firms_Number'])

EFR_Administrative_and_Support_and_Waste_Management_and_Remediation_Services = Administrative_and_Support_and_Waste_Management_and_Remediation_Services['Annual_Payroll'].div(Administrative_and_Support_and_Waste_Management_and_Remediation_Services['Employment'])
APFR_Administrative_and_Support_and_Waste_Management_and_Remediation_Services = Administrative_and_Support_and_Waste_Management_and_Remediation_Services['Annual_Payroll'].div(Administrative_and_Support_and_Waste_Management_and_Remediation_Services['Firms_Number'])

EFR_Other_Services_Except_Public_Administration = Other_Services_Except_Public_Administration['Annual_Payroll'].div(Other_Services_Except_Public_Administration['Employment'])
APFR_Other_Services_Except_Public_Administration = Other_Services_Except_Public_Administration['Annual_Payroll'].div(Other_Services_Except_Public_Administration['Firms_Number'])

EFR_Educational_Services = Educational_Services['Annual_Payroll'].div(Educational_Services['Employment'])
APFR_Educational_Services = Educational_Services['Annual_Payroll'].div(Educational_Services['Firms_Number'])

EFR_Real_Estate_and_Rental_and_Leasing = Real_Estate_and_Rental_and_Leasing['Annual_Payroll'].div(Real_Estate_and_Rental_and_Leasing['Employment'])
APFR_Real_Estate_and_Rental_and_Leasing = Real_Estate_and_Rental_and_Leasing['Annual_Payroll'].div(Real_Estate_and_Rental_and_Leasing['Firms_Number'])

EFR_Construction = Construction['Annual_Payroll'].div(Construction['Employment'])
APFR_Construction = Construction['Annual_Payroll'].div(Construction['Firms_Number'])

EFR_Manufacturing = Manufacturing['Annual_Payroll'].div(Manufacturing['Employment'])
APFR_Manufacturing = Manufacturing['Annual_Payroll'].div(Manufacturing['Firms_Number'])

EFR_Information = Information['Annual_Payroll'].div(Information['Employment'])
APFR_Information = Information['Annual_Payroll'].div(Information['Firms_Number'])

EFR_Management_of_Companies_and_Enterprises = Management_of_Companies_and_Enterprises['Annual_Payroll'].div(Management_of_Companies_and_Enterprises['Employment'])
APFR_Management_of_Companies_and_Enterprises = Management_of_Companies_and_Enterprises['Annual_Payroll'].div(Management_of_Companies_and_Enterprises['Firms_Number'])

EFR_Arts_Entertainment_and_Recreation = Arts_Entertainment_and_Recreation['Annual_Payroll'].div(Arts_Entertainment_and_Recreation['Employment'])
APFR_Arts_Entertainment_and_Recreation = Arts_Entertainment_and_Recreation['Annual_Payroll'].div(Arts_Entertainment_and_Recreation['Firms_Number'])

EFR_Mining_Quarrying_and_Oil_and_Gas_Extraction = Mining_Quarrying_and_Oil_and_Gas_Extraction['Annual_Payroll'].div(Mining_Quarrying_and_Oil_and_Gas_Extraction['Employment'])
APFR_Mining_Quarrying_and_Oil_and_Gas_Extraction = Mining_Quarrying_and_Oil_and_Gas_Extraction['Annual_Payroll'].div(Mining_Quarrying_and_Oil_and_Gas_Extraction['Firms_Number'])

EFR_Utilities = Utilities['Annual_Payroll'].div(Utilities['Employment'])
APFR_Utilities = Utilities['Annual_Payroll'].div(Utilities['Firms_Number'])

EFR_Industries_not_classified = Industries_not_classified['Annual_Payroll'].div(Industries_not_classified['Employment'])
APFR_Industries_not_classified = Industries_not_classified['Annual_Payroll'].div(Industries_not_classified['Firms_Number'])

# %%
import bokeh 
from bokeh.plotting import figure, show
from bokeh.layouts import row, gridplot
from bokeh.io import export_png



# Agriculture, Forestry, Fishing and Hunting
y = EFR_BIG_AG
x = APFR_BIG_AG
# Health Care and Social Assistance
y2 = EFR_Health_n_Social
x2 = APFR_Health_n_Social
# Accomodation and Food Services
y3 = EFR_Accommodation_and_Food_Services
x3 = APFR_Accommodation_and_Food_Services
#Professional and Scientific, Technical Services
y4 = EFR_Professional_Scientific_and_Technical_Services
x4 = APFR_Professional_Scientific_and_Technical_Services
# Retail Trade
y5 = EFR_Retail_Trade
x5 = APFR_Retail_Trade
# Transportation and Warehousing
y6 = EFR_Transportation_and_Warehousing
x6 = APFR_Transportation_and_Warehousing
# Wholesale Trade
y7 = EFR_Wholesale_Trade
x7 = APFR_Wholesale_Trade
# Finance and Insurance
y8 = EFR_Finance_and_Insurance
x8 = APFR_Finance_and_Insurance
# Administrative and Support and Waste Management and Remediation Services
y9 = EFR_Administrative_and_Support_and_Waste_Management_and_Remediation_Services
x9 = APFR_Administrative_and_Support_and_Waste_Management_and_Remediation_Services
# Other Services Except Public Administration
y10 = EFR_Other_Services_Except_Public_Administration
x10 = APFR_Other_Services_Except_Public_Administration
# Educational Services
y11 = EFR_Educational_Services
x11 = APFR_Educational_Services
# Real Estate and Rental and Leasing
y12 = EFR_Real_Estate_and_Rental_and_Leasing
x12 = APFR_Real_Estate_and_Rental_and_Leasing
# Construction
y13 = EFR_Construction
x13 = APFR_Construction
# Manufacturing
y14 = EFR_Manufacturing
x14 = APFR_Manufacturing
# Information
y15 = EFR_Information
x15 = APFR_Information
# Management of Companies and Enterprises
y16 = EFR_Management_of_Companies_and_Enterprises
x16 = APFR_Management_of_Companies_and_Enterprises
# Arts Entertainment and Recreation
y17 = EFR_Arts_Entertainment_and_Recreation
x17 = APFR_Arts_Entertainment_and_Recreation
# Mining Quarrying and Oil and Gas Extraction
y18 = EFR_Mining_Quarrying_and_Oil_and_Gas_Extraction
x18 = APFR_Mining_Quarrying_and_Oil_and_Gas_Extraction
# Utilities
y19 = EFR_Utilities
x19 = APFR_Utilities
# Industries not classified
y20 = EFR_Industries_not_classified
x20 = APFR_Industries_not_classified

x_name = 'Payroll/Firms'
y_name = 'Payroll/Employees'
label = 'Average Salary to Average Payroll per Firm'
size = 6
line_width = 1



# Plot 1
p = figure(title="Agriculture, Forestry, Fishing and Hunting Average Employees per Firm to Average Annual Payroll per Firm", x_axis_label='Payroll/Firms', y_axis_label='Payroll/Employment')
p.grid.visible = True
p.scatter(x, y, legend_label=label, fill_color="blue",line_width=line_width, size=size)
#p.scatter(x,y,legend_label="Payroll (mils) to Employment", line_width=1)

# Plot 2
p2 = figure(title="Health Care and Social Assistance Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p2.grid.visible = True
p2.scatter(x2, y2, legend_label=label, line_width=line_width, size=size, color="green")

# Plot 3
p3 = figure(title="Accomodation and Food Services Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p3.grid.visible = True
p3.scatter(x3, y3, legend_label=label, line_width=line_width, size=size, color="orange")

# Plot 4
p4 = figure(title="Professional, Scientific and Technical Services Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p4.grid.visible = True
p4.scatter(x4, y4, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 5
p5 = figure(title="Retail Trade Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p5.grid.visible = True
p5.scatter(x5, y5, legend_label=label, fill_color="red", line_width=line_width, size=size)

# Plot 6
p6 = figure(title="Transportation and Warehousing Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p6.grid.visible = True
p6.scatter(x6, y6, legend_label=label, fill_color="green", line_width=line_width, size=size)

# Plot 7
p7 = figure(title="Wholesale Trade Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p7.grid.visible = True
p7.scatter(x7, y7, legend_label=label, fill_color="red", line_width=line_width, size=size)

# Plot 8
p8 = figure(title="Finance and Insurance Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p8.grid.visible = True
p8.scatter(x8, y8, legend_label=label, fill_color="purple", line_width=line_width, size=size)

# Plot 9
p9 = figure(title="Administrative and Support and Waste Management and Remediation Services Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p9.grid.visible = True
p9.scatter(x9, y9, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 10
p10 = figure(title="Other Services Except Public Administration Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p10.grid.visible = True
p10.scatter(x10, y10, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 11
p11 = figure(title="Educational Services Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p11.grid.visible = True
p11.scatter(x11, y11, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 12
p12 = figure(title="Real Estate and Rental and Leasing Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p12.grid.visible = True
p12.scatter(x12, y12, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 13
p13 = figure(title="Construction Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p13.grid.visible = True
p13.scatter(x13, y13, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 14
p14 = figure(title="Manufacturing Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p14.grid.visible = True
p14.scatter(x14, y14, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 15
p15 = figure(title="Information Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p15.grid.visible = True
p15.scatter(x15, y15, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 16
p16 = figure(title="Management of Companies and Enterprises Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p16.grid.visible = True
p16.scatter(x16, y16, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 17
p17 = figure(title="Arts Entertainment and Recreation Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p17.grid.visible = True
p17.scatter(x17, y17, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 18
p18 = figure(title="Mining Quarrying and Oil and Gas Extraction Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p18.grid.visible = True
p18.scatter(x18, y18, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 19
p19 = figure(title="Utilities Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p19.grid.visible = True
p19.scatter(x19, y19, legend_label=label, fill_color="orange", line_width=line_width, size=size)

# Plot 20
p20 = figure(title="Industries not classified Pay Drop Off", x_axis_label=x_name, y_axis_label=y_name)
p20.grid.visible = True
p20.scatter(x20, y20, legend_label=label, fill_color="orange", line_width=line_width, size=size)



# show the results
grid = gridplot([[p, p2, p3],
                 [p4, p5, p6],
                 [p7, p8, p9],
                 [p10, p11, p12],
                 [p13, p14, p15]], plot_width=450, plot_height=450)


show(grid)
export_png(grid, filename="plot.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93dbec4cf269> in <module>
#       7
#       8 # Agriculture, Forestry, Fishing and Hunting
# ----> 9 y = EFR_BIG_AG
#      10 x = APFR_BIG_AG
#      11 # Health Care and Social Assistance
#
# NameError: name 'EFR_BIG_AG' is not defined

# %%
EFR_Professional_Scientific_and_Technical_Services.describe()
# Out:
# count       19.000000
# mean     74265.849448
# std      10302.926729
# min      57635.421083
# 25%      65533.562691
# 50%      73296.524526
# 75%      79508.675534
# max      95065.808321
# dtype: float64

# %%
# conda install selenium geckodriver firefox -c conda-forge

# %%
# df_employment.str.replace(',', '')
# df_payroll.str.replace(',', '')
# df_employment = pd.to_numeric(df_employment, errors='coerce')
# df_payroll = pd.to_numeric(df_payroll, errors='coerce')
